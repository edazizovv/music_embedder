# %%
import numpy
import pandas
import pytube
import datetime
import requests
from json import loads
from pytube import YouTube

# %%
f = open("all.txt", "r")
links_to_read = f.read().split('\n')
links_to_read
# Out:
# ['https://www.youtube.com/watch?v=VNhsh1YW8Co',
#  'https://www.youtube.com/watch?v=HlP8B0KrJxk',
#  'https://www.youtube.com/watch?v=NhrV6H78CCc',
#  'https://www.youtube.com/watch?v=i_IYl_D5yh4',
#  'https://www.youtube.com/watch?v=hYA2d88vYOs',
#  'https://www.youtube.com/watch?v=cSPfeTwl8Kw',
#  'https://www.youtube.com/watch?v=2PN548CszJ4',
#  'https://www.youtube.com/watch?v=GzeBHIto4Ps',
#  'https://www.youtube.com/watch?v=kWam-Hh2lxE',
#  'https://www.youtube.com/watch?v=7SpIvGqi5Wk',
#  'https://www.youtube.com/watch?v=aJIDqYZ7qM0',
#  'https://www.youtube.com/watch?v=PLe3pznz9oM',
#  'https://www.youtube.com/watch?v=fe8yiBw1ydc',
#  'https://www.youtube.com/watch?v=36v6XBpa7CA',
#  'https://www.youtube.com/watch?v=u1_KbKR_sng',
#  'https://www.youtube.com/watch?v=UnRRb4BCsqE',
#  'https://www.youtube.com/watch?v=SG2TUTIFwSE',
#  'https://www.youtube.com/watch?v=WTS7HBGpy5c',
#  'https://www.youtube.com/watch?v=2PN548CszJ4',
#  'https://www.youtube.com/watch?v=9mKCj4Nigpg',
#  'https://www.youtube.com/watch?v=kvAd76GacPg',
#  'https://www.youtube.com/watch?v=PGNiXGX2nLU',
#  'https://www.youtube.com/watch?v=A7Pv8Tg4C2Q',
#  'https://www.youtube.com/watch?v=vT5tC-qZ3lI',
#  'https://www.youtube.com/watch?v=iN80A6cSBxY',
#  'https://www.youtube.com/watch?v=iC-vWZzTPms',
#  'https://www.youtube.com/watch?v=6oFwfkx-3lg',
#  'https://www.youtube.com/watch?v=TqKFb72EyTM',
#  'https://www.youtube.com/watch?v=OcSsojXfGIs',
#  'https://www.youtube.com/watch?v=ZSmJVeujJCE',
#  'https://www.youtube.com/watch?v=CqMFclGDA20',
#  'https://www.youtube.com/watch?v=LTkidXJXYTo',
#  'https://www.youtube.com/watch?v=9o2QPoPlhVI',
#  'https://www.youtube.com/watch?v=DDyoU8Rs-lE',
#  'https://www.youtube.com/watch?v=LzEikWuxUFU',
#  'https://www.youtube.com/watch?v=82FDvDi05w0',
#  'https://www.youtube.com/watch?v=AMpvHWfXNFs',
#  'https://www.youtube.com/watch?v=BBEAZkmbyeY',
#  'https://www.youtube.com/watch?v=pOpG9xyjsDY',
#  'https://www.youtube.com/watch?v=d8081_cQZyY',
#  'https://www.youtube.com/watch?v=9gM7FUXeIb0',
#  'https://www.youtube.com/watch?v=NwfODOAY0iY',
#  'https://www.youtube.com/watch?v=MckVEuUh_yI',
#  'https://www.youtube.com/watch?v=iaDvKKGKAlQ',
#  'https://www.youtube.com/watch?v=YJxSATlIgAg',
#  'https://www.youtube.com/watch?v=m1wViPkNq3A',
#  'https://www.youtube.com/watch?v=lhGE5brBvNQ',
#  'https://www.youtube.com/watch?v=nvMlrVdTsao',
#  'https://www.youtube.com/watch?v=0poLsDf1TvM',
#  'https://www.youtube.com/watch?v=IkncOaW6nJE',
#  'https://www.youtube.com/watch?v=wT-3tH3yrzI',
#  'https://www.youtube.com/watch?v=OBFA6cr2-6A',
#  'https://www.youtube.com/watch?v=mgDDgXgoG30',
#  'https://www.youtube.com/watch?v=oNjq8SUArRU',
#  'https://www.youtube.com/watch?v=G3lkluCt5-Y',
#  'https://www.youtube.com/watch?v=RwJscjiB0Sc',
#  'https://www.youtube.com/watch?v=Rzs3beBNT9g',
#  'https://www.youtube.com/watch?v=XGUy0__LJKw',
#  'https://www.youtube.com/watch?v=FRSTaBZfxK4',
#  'https://www.youtube.com/watch?v=XGUy0__LJKw',
#  'https://www.youtube.com/watch?v=zTpycqGYRRM',
#  'https://www.youtube.com/watch?v=FXk7qopHCMY',
#  'https://www.youtube.com/watch?v=z0jOyz222qc',
#  'https://www.youtube.com/watch?v=1AfkQES9PPw',
#  'https://www.youtube.com/watch?v=aChhwFF_SNQ',
#  'https://www.youtube.com/watch?v=FIgQGRY0EmU',
#  'https://www.youtube.com/watch?v=fJtBo36ke3g',
#  'https://www.youtube.com/watch?v=PAmhPY5szZ8',
#  'https://www.youtube.com/watch?v=6A4A9Xkx6Xo',
#  'https://www.youtube.com/watch?v=XGhdSeKr4TM',
#  'https://www.youtube.com/watch?v=HfWlHvzu20Y',
#  'https://www.youtube.com/watch?v=OCWanch3NBk',
#  'https://www.youtube.com/watch?v=-PVZWsClTPY',
#  'https://www.youtube.com/watch?v=6KDvQz-YfKY',
#  'https://www.youtube.com/watch?v=x-XNgm66eeM',
#  'https://www.youtube.com/watch?v=6QdLsPBa30o',
#  'https://www.youtube.com/watch?v=gBZi2w11XxU',
#  'https://www.youtube.com/watch?v=FdJ_SGof2GI',
#  'https://www.youtube.com/watch?v=7MmhdFwERjE',
#  'https://www.youtube.com/watch?v=OepFO4Nisms',
#  'https://www.youtube.com/watch?v=vRq0eD6c4JY',
#  'https://www.youtube.com/watch?v=B6XZRAtrPJU',
#  'https://www.youtube.com/watch?v=VabgrlvtzLg',
#  'https://www.youtube.com/watch?v=5mHYwdeBDAE',
#  'https://www.youtube.com/watch?v=D6_b4Iueeo8',
#  'https://www.youtube.com/watch?v=Fo-dHb8GTI8',
#  'https://www.youtube.com/watch?v=A5oXyThssps',
#  'https://www.youtube.com/watch?v=6spnsA8dQwA',
#  'https://www.youtube.com/watch?v=Xv_SV_ki_Q0',
#  'https://www.youtube.com/watch?v=yw6ZjMyreDY',
#  'https://www.youtube.com/watch?v=CvRGpXtNc1o',
#  'https://www.youtube.com/watch?v=1VgqTZptlt4',
#  'https://www.youtube.com/watch?v=xLeGykSUFdY',
#  'https://www.youtube.com/watch?v=DGKayhZqZRU',
#  'https://www.youtube.com/watch?v=zeYu80utaf8',
#  'https://www.youtube.com/watch?v=thz_JqagxRU',
#  'https://www.youtube.com/watch?v=QwTiL9-9ezs',
#  'https://www.youtube.com/watch?v=st-ZjwCy4uo',
#  'https://www.youtube.com/watch?v=7HiOuTpi5dg',
#  'https://www.youtube.com/watch?v=hXkB92fjCgo',
#  'https://www.youtube.com/watch?v=st-ZjwCy4uo',
#  'https://www.youtube.com/watch?v=oDm0rpvL4A8',
#  'https://www.youtube.com/watch?v=XJqe3EUGbQM',
#  'https://www.youtube.com/watch?v=SS-9nTMidqY',
#  'https://www.youtube.com/watch?v=LPt1N_ba934',
#  'https://www.youtube.com/watch?v=JwEKYSLuwUo',
#  'https://www.youtube.com/watch?v=ch-HHGuzwRU',
#  'https://www.youtube.com/watch?v=xhsIu3iBBQw',
#  'https://www.youtube.com/watch?v=XWNsWZ5VtWc',
#  'https://www.youtube.com/watch?v=bpOSxM0rNPM',
#  'https://www.youtube.com/watch?v=0j7_Tb4LgPA',
#  'https://www.youtube.com/watch?v=v0nmHymgM7Y',
#  'https://www.youtube.com/watch?v=xdOykEJSXIg',
#  'https://www.youtube.com/watch?v=pT-RkWoRcJg',
#  'https://www.youtube.com/watch?v=u4edBTV5_Uk',
#  'https://www.youtube.com/watch?v=sKqfeWQOOZk',
#  'https://www.youtube.com/watch?v=AFNZosSiNRI',
#  'https://www.youtube.com/watch?v=QlXrndlCFIk',
#  'https://www.youtube.com/watch?v=i4EYGBeR97k',
#  'https://www.youtube.com/watch?v=Jmz8xIK9Gts',
#  'https://www.youtube.com/watch?v=HYVXIFfi5N0',
#  'https://www.youtube.com/watch?v=huY252lNzx4',
#  'https://www.youtube.com/watch?v=xglkW65SEeM',
#  'https://www.youtube.com/watch?v=40PLk5VKVKQ',
#  'https://www.youtube.com/watch?v=DIQRZkXB9Qk',
#  'https://www.youtube.com/watch?v=8ZspunA4HlM',
#  'https://www.youtube.com/watch?v=7MmhdFwERjE',
#  'https://www.youtube.com/watch?v=BtXec1z00pM',
#  'https://www.youtube.com/watch?v=p9aUfwgkoc4',
#  'https://www.youtube.com/watch?v=k5xDyG72wHE',
#  'https://www.youtube.com/watch?v=cSPfeTwl8Kw',
#  'https://www.youtube.com/watch?v=LkoTnDuyrY4',
#  'https://www.youtube.com/watch?v=Eiijm2GhKAA',
#  'https://www.youtube.com/watch?v=kyquqw6GeXk',
#  'https://www.youtube.com/watch?v=h8rGckNsF-M',
#  'https://www.youtube.com/watch?v=NzgB1MkxBAk',
#  'https://www.youtube.com/watch?v=36qnhrJGgfc',
#  'https://www.youtube.com/watch?v=7bGh-3EdUog',
#  'https://www.youtube.com/watch?v=x-XNgm66eeM',
#  'https://www.youtube.com/watch?v=91GTuZWCQmY',
#  'https://www.youtube.com/watch?v=tE_7HeBZgYE',
#  'https://www.youtube.com/watch?v=Xjr7xx4-dZg',
#  'https://www.youtube.com/watch?v=xsJNjEo2pWU',
#  'https://www.youtube.com/watch?v=XmBgq47QEh8',
#  'https://www.youtube.com/watch?v=6bCbpnEssXw',
#  'https://www.youtube.com/watch?v=p4VBh7WFvZM',
#  'https://www.youtube.com/watch?v=dw0LBddkgHw',
#  'https://www.youtube.com/watch?v=Z4PSx_teHD0']

# %%
def get_description(video: YouTube) -> str:
    i: int = video.watch_html.find('"shortDescription":"')
    desc: str = '"'
    i += 20  # excluding the `"shortDescription":"`
    while True:
        letter = video.watch_html[i]
        desc += letter  # letter can be added in any case
        i += 1
        if letter == '\\':
            desc += video.watch_html[i]
            i += 1
        elif letter == '"':
            break
    return loads(desc)

def get_thumb(name, thumb):
    img_data = requests.get(thumb).content
    with open('./thumbs/{0}.png'.format(name), 'wb') as handler:
        handler.write(img_data)

# %%
names, authors, descriptions, ratings, thumbs, titles, nn_views, lengths = [], [], [], [], [], [], [], []
for l in links_to_read:
    name = l[l.index('?v=')+len('?v='):]
    print(name)
    try:
        yy = YouTube(l)
        yy.check_availability()
        author = yy.author
        # description = yy.description
        description = get_description(yy)
        rating = yy.rating
        thumb = yy.thumbnail_url
        get_thumb(name, thumb)
        title = yy.title
        n_views = yy.views
        length = yy.length
        # yy.streams.first().download(output_path='data\\', filename='{0}.mp4'.format(name))
    except Exception as e:
        print(e)
        author = ''
        description = ''
        rating = numpy.nan
        thumb = ''
        title = ''
        n_views = numpy.nan
        length = numpy.nan
    names.append(name)
    authors.append(author)
    descriptions.append(description)
    ratings.append(rating)
    thumbs.append(thumb)
    titles.append(title)
    nn_views.append(n_views)
    lengths.append(length)
thumbnails = ['{0}.png'.format(name) for name in names]
summary = pandas.DataFrame(data={'_name': titles,
                                 '_author': authors,
                                 '_description': descriptions,
                                 '_link': links_to_read,
                                 'thumbnail': thumbnails,
                                 })
now = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
summary.to_excel('./summary_{0}.xlsx'.format(now), index=False)
summary
# Out:
# VNhsh1YW8Co
# HlP8B0KrJxk
# NhrV6H78CCc
# i_IYl_D5yh4
# hYA2d88vYOs
# cSPfeTwl8Kw
# 2PN548CszJ4
# GzeBHIto4Ps
# kWam-Hh2lxE
# 7SpIvGqi5Wk
# aJIDqYZ7qM0
# PLe3pznz9oM
# fe8yiBw1ydc
# 36v6XBpa7CA
# u1_KbKR_sng
# UnRRb4BCsqE
# SG2TUTIFwSE
# WTS7HBGpy5c
# 2PN548CszJ4
# 9mKCj4Nigpg
# kvAd76GacPg
# PGNiXGX2nLU
# A7Pv8Tg4C2Q
# vT5tC-qZ3lI
# iN80A6cSBxY
# iC-vWZzTPms
# 6oFwfkx-3lg
# TqKFb72EyTM
# OcSsojXfGIs
# ZSmJVeujJCE
# CqMFclGDA20
# LTkidXJXYTo
# 9o2QPoPlhVI
# DDyoU8Rs-lE
# LzEikWuxUFU
# 82FDvDi05w0
# AMpvHWfXNFs
# BBEAZkmbyeY
# pOpG9xyjsDY
# d8081_cQZyY
# 9gM7FUXeIb0
# NwfODOAY0iY
# MckVEuUh_yI
# iaDvKKGKAlQ
# YJxSATlIgAg
# m1wViPkNq3A
# lhGE5brBvNQ
# nvMlrVdTsao
# 0poLsDf1TvM
# IkncOaW6nJE
# wT-3tH3yrzI
# OBFA6cr2-6A
# mgDDgXgoG30
# oNjq8SUArRU
# G3lkluCt5-Y
# RwJscjiB0Sc
# Rzs3beBNT9g
# XGUy0__LJKw
# FRSTaBZfxK4
# XGUy0__LJKw
# zTpycqGYRRM
# FXk7qopHCMY
# z0jOyz222qc
# 1AfkQES9PPw
# aChhwFF_SNQ
# FIgQGRY0EmU
# fJtBo36ke3g
# PAmhPY5szZ8
# 6A4A9Xkx6Xo
# XGhdSeKr4TM
# HfWlHvzu20Y
# OCWanch3NBk
# -PVZWsClTPY
# 6KDvQz-YfKY
# x-XNgm66eeM
# 6QdLsPBa30o
# gBZi2w11XxU
# FdJ_SGof2GI
# 7MmhdFwERjE
# OepFO4Nisms
# vRq0eD6c4JY
# B6XZRAtrPJU
# VabgrlvtzLg
# 5mHYwdeBDAE
# D6_b4Iueeo8
# Fo-dHb8GTI8
# A5oXyThssps
# 6spnsA8dQwA
# Xv_SV_ki_Q0
# yw6ZjMyreDY
# CvRGpXtNc1o
# 1VgqTZptlt4
# xLeGykSUFdY
# DGKayhZqZRU
# zeYu80utaf8
# thz_JqagxRU
# QwTiL9-9ezs
# st-ZjwCy4uo
# 7HiOuTpi5dg
# hXkB92fjCgo
# st-ZjwCy4uo
# oDm0rpvL4A8
# XJqe3EUGbQM
# SS-9nTMidqY
# LPt1N_ba934
# JwEKYSLuwUo
# ch-HHGuzwRU
# xhsIu3iBBQw
# XWNsWZ5VtWc
# bpOSxM0rNPM
# 0j7_Tb4LgPA
# v0nmHymgM7Y
# xdOykEJSXIg
# pT-RkWoRcJg
# u4edBTV5_Uk
# sKqfeWQOOZk
# AFNZosSiNRI
# QlXrndlCFIk
# i4EYGBeR97k
# Jmz8xIK9Gts
# HYVXIFfi5N0
# huY252lNzx4
# xglkW65SEeM
# 40PLk5VKVKQ
# DIQRZkXB9Qk
# 8ZspunA4HlM
# 7MmhdFwERjE
# BtXec1z00pM
# p9aUfwgkoc4
# k5xDyG72wHE
# cSPfeTwl8Kw
# LkoTnDuyrY4
# Eiijm2GhKAA
# kyquqw6GeXk
# h8rGckNsF-M
# NzgB1MkxBAk
# 36qnhrJGgfc
# 7bGh-3EdUog
# x-XNgm66eeM
# 91GTuZWCQmY
# tE_7HeBZgYE
# Xjr7xx4-dZg
# xsJNjEo2pWU
# XmBgq47QEh8
# 6bCbpnEssXw
# p4VBh7WFvZM
# dw0LBddkgHw
# Z4PSx_teHD0
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[36], line 43
#      36 summary = pandas.DataFrame(data={'_name': titles,
#      37                                  '_author': authors,
#      38                                  '_description': descriptions,
#      39                                  '_link': links_to_read,
#      40                                  'thumbnail': thumbnails,
#      41                                  })
#      42 now = datetime.datetime.now().isoformat()
# ---> 43 summary.to_excel('./summary_{0}.xlsx'.format(now))
#      44 summary
#
# File C:\TET\env\music\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File C:\TET\env\music\Lib\site-packages\pandas\core\generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2404 from pandas.io.formats.excel import ExcelFormatter
#    2406 formatter = ExcelFormatter(
#    2407     df,
#    2408     na_rep=na_rep,
#    (...)
#    2415     inf_rep=inf_rep,
#    2416 )
# -> 2417 formatter.write(
#    2418     excel_writer,
#    2419     sheet_name=sheet_name,
#    2420     startrow=startrow,
#    2421     startcol=startcol,
#    2422     freeze_panes=freeze_panes,
#    2423     engine=engine,
#    2424     storage_options=storage_options,
#    2425     engine_kwargs=engine_kwargs,
#    2426 )
#
# File C:\TET\env\music\Lib\site-packages\pandas\io\formats\excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File C:\TET\env\music\Lib\site-packages\pandas\io\excel\_xlsxwriter.py:204, in XlsxWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     201 if mode == "a":
#     202     raise ValueError("Append mode is not supported with xlsxwriter!")
# --> 204 super().__init__(
#     205     path,
#     206     engine=engine,
#     207     date_format=date_format,
#     208     datetime_format=datetime_format,
#     209     mode=mode,
#     210     storage_options=storage_options,
#     211     if_sheet_exists=if_sheet_exists,
#     212     engine_kwargs=engine_kwargs,
#     213 )
#     215 try:
#     216     self._book = Workbook(self._handles.handle, **engine_kwargs)
#
# File C:\TET\env\music\Lib\site-packages\pandas\io\excel\_base.py:1246, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1242 self._handles = IOHandles(
#    1243     cast(IO[bytes], path), compression={"compression": None}
#    1244 )
#    1245 if not isinstance(path, ExcelWriter):
# -> 1246     self._handles = get_handle(
#    1247         path, mode, storage_options=storage_options, is_text=False
#    1248     )
#    1249 self._cur_sheet = None
#    1251 if date_format is None:
#
# File C:\TET\env\music\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# OSError: [Errno 22] Invalid argument: './summary_2024-08-11T16:15:22.012826.xlsx'

# %%
summary
# Out:
#                                                  _name  \
# 0                                            Ciao Ciao
# 1          Dark Chantings Temple Occult Music - TEMPLE
# 2    Dies Irae - Occult Dark Ambient Music - Gregor...
# 3                                        BURNING SOULS
# 4    The Donnies The Amys - Drive You Home | Suits ...
# ..                                                 ...
# 143  KUTE x KORDHELL - DEAD ON ARRIVAL (Slowed + Re...
# 144                                INTO THE FIRE PHONK
# 145                              Cupid (Phonk Version)
# 146         The Perfect Girl ((Instrumental) [Slowed])
# 147                 Mr Krabs - In Da Club (A.I. Cover)
#
#                         _author  \
# 0    La Rappresentante di Lista
# 1                       Santino
# 2                   Myers Music
# 3                     MoonDeity
# 4                   Suits Music
# ..                          ...
# 143                     H X N G
# 144                       DRYKE
# 145                       DRYKE
# 146                      Mareux
# 147                   Zermpinos
#
#                                           _description  \
# 0    La Rappresentante di Lista - Ciao Ciao (Testo)...
# 1    Instagram :https://www.instagram.com/reyan.san...
# 2    Download my Music: https://myersmusic.bandcamp...
# 3
# 4
# ..                                                 ...
# 143  Subscribe to my channel for more music.\n\nCon...
# 144
# 145
# 146  Provided to YouTube by Revolution Records\n\nT...
# 147                      Cover made with crepe. Enjoy!
#
#                                            _link        thumbnail
# 0    https://www.youtube.com/watch?v=VNhsh1YW8Co  VNhsh1YW8Co.png
# 1    https://www.youtube.com/watch?v=HlP8B0KrJxk  HlP8B0KrJxk.png
# 2    https://www.youtube.com/watch?v=NhrV6H78CCc  NhrV6H78CCc.png
# 3    https://www.youtube.com/watch?v=i_IYl_D5yh4  i_IYl_D5yh4.png
# 4    https://www.youtube.com/watch?v=hYA2d88vYOs  hYA2d88vYOs.png
# ..                                           ...              ...
# 143  https://www.youtube.com/watch?v=XmBgq47QEh8  XmBgq47QEh8.png
# 144  https://www.youtube.com/watch?v=6bCbpnEssXw  6bCbpnEssXw.png
# 145  https://www.youtube.com/watch?v=p4VBh7WFvZM  p4VBh7WFvZM.png
# 146  https://www.youtube.com/watch?v=dw0LBddkgHw  dw0LBddkgHw.png
# 147  https://www.youtube.com/watch?v=Z4PSx_teHD0  Z4PSx_teHD0.png
#
# [148 rows x 5 columns]
